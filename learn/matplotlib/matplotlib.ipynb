# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
a = np.arange(0, math.pi*2, 0.05)
b = np.sin(a)
plt.title('sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(a, b)
plt.show()

# %%
# figure  图形对象
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.set_title("sin(x)")
ax.set_xlabel("angle")
ax.set_ylabel("sine")
ax.plot(a, b)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title("sin(x)")
ax.set_xlabel("angle")
ax.set_ylabel("sine")
ax.plot(a, b)
plt.show()

# %%
y = [1, 4, 9, 16, 25,36,49, 64]
x1 = [1, 16, 30, 42,55, 68, 77,88]
x2 = [1,6,12,18,28, 40, 52, 65]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x1, y, 'go--')
ax.plot(x2, y, 'ys-')
ax.set_xlabel('medium')
ax.set_ylabel('sales')
ax.set_title('Advertisement effect on sales')
ax.legend(labels=('tv', 'Smartphone'), loc='lower right')

plt.show()

# %%
plt.plot([1, 2, 3])
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, facecolor='y')
plt.plot(range(12))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot([1, 2, 3])
ax2 = fig.add_subplot(221, facecolor='y')
ax2.plot([1, 2, 3])

# %%
x = np.arange(0, math.pi*2, 0.05)
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])  # main axes
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3])  # insert axes
y = np.sin(x)
axes1.plot(x, y, 'b')
axes2.plot(x, np.cos(x), 'r')
axes1.set_title('sine')
axes2.set_title('cosine')
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
x = np.arange(1, 5)
ax[0][0].plot(x, x**x)
ax[0][0].set_title('square')
ax[0][1].plot(x, np.sqrt(x))
ax[0][1].set_title('square root')
ax[1][0].plot(x, np.exp(x))
ax[1][0].set_title('exp')
ax[1][1].plot(x,np.log10(x))
ax[1][1].set_title('log')
ax[1][1].set_xlabel('x')
plt.show()

# %%
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=2)
ax2 = plt.subplot2grid((3, 3), (0, 2), rowspan=3)
ax3 = plt.subplot2grid((3, 3), (1, 0), rowspan=2, colspan=2)
x = np.arange(1, 10)
ax1.plot(x, np.exp(x))
ax1.set_title('exp')
ax2.plot(x, np.square(x))
ax2.set_title('square')
ax3.plot(x, np.log(x))
ax3.set_title('log')
plt.tight_layout()  # 自动调整子图参数，使之充满整个绘图区域
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
x = np.arange(1, 11)
axes[0].plot(x, x**3, 'g', lw=2)
# 开启网格
axes[0].grid(True)
axes[0].set_title('default grid')
axes[0].plot(x, np.exp(x), 'r')
# 设置网格的颜色，线性，线宽
axes[1].grid(color='b', ls='-.', lw=0.25)
axes[1].set_title('custom grid')
axes[1].plot(x, np.exp(x), 'r')
axes[2].plot(x, x)
axes[2].set_title('no grid')
fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
x = np.arange(1, 5)
axes[0].plot(x, np.exp(x))
axes[0].plot(x, x**2)
axes[0].set_title('Norman scale')
axes[0].set_xlabel('x axis')
axes[0].set_ylabel('y axis')
axes[0].xaxis.labelpad = 10
axes[1].plot(x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_title('Logarithmic scale (y)')
axes[1].set_yscale('log')
axes[1].set_xlabel('x axis')
axes[1].set_ylabel('y axis')
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.spines['bottom'].set_color('blue')
ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_color(None)
ax.spines['top'].set_color(None)
plt.plot([1, 2, 3, 4, 5])
plt.show()

# %%
fig = plt.figure()
a1 = fig.add_axes([0, 0, 1, 1])
x = np.arange(1, 10)
a1.plot(x, np.exp(x))
a1.set_title('exp')
plt.show()

# %%
fig = plt.figure()
a1 = fig.add_axes([0, 0, 1, 1])
x = np.arange(1, 10)
a1.plot(x, np.exp(x), 'r')
a1.set_title('exp')
a1.set_ylim(0, 10000)
a1.set_xlim(0, 10)
plt.show()

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(x, y)
ax.set_xlabel('angle')
ax.set_title('sine')
ax.set_xticks([0, math.pi*0.5, math.pi, math.pi*1.5, math.pi*2])
ax.set_xticklabels(['0', 'pi/2', 'pi', '1.5pi', '2pi'])
ax.set_yticks([-1, 0, 1])
plt.show()

# %%
# 绘制折线图
plt.rcParams["font.sans-serif"] = ["SimHei"]  # 设置字体
plt.rcParams["axes.unicode_minus"] = False    # 正常显示负号
year = [2017, 2018, 2019, 2020]
people = [20, 40, 60, 70]
plt.plot(year, people)
plt.xlabel('年份')
plt.ylabel('人口')
plt.title('人口增长')
plt.yticks([0, 20, 40, 60, 80])
plt.fill_between(year, people, 20, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-8, 8, 1024)
y1 = 0.618 * np.abs(x) - 0.8 * np.sqrt(64 - x ** 2)
y2 = 0.618 * np.abs(x) + 0.8 * np.sqrt(64 - x ** 2)
plt.plot(x, y1, color='r')
plt.plot(x, y2, color='r')
plt.title("我爱C语言中文网",fontsize=20,color="b")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
a1 = fig.add_axes([0, 0, 1, 1,])
x = np.arange(1, 11)
a1.plot(x, np.exp(x))
a1.set_ylabel('exp')
a2 = a1.twinx()
a2.plot(x, np.log(x), 'ro-')
a2.set_ylabel('log')
fig.legend(labels=('exp', 'log'), loc='upper left')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
langs = ['C', 'C++', 'java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]
ax.bar(langs, students)
plt.show()

# %% [markdown]
# ## 同位置多柱状图

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]  # 设置字体
plt.rcParams["axes.unicode_minus"] = False    # 正常显示负号
# 区域
areas = ['安徽', '北京', '上海', '云南', '香港']
# 金牌个数
gold_medel = [16, 12, 9, 8, 8]
# 银牌个数
silver_medal = [8, 10, 4, 10, 5]
# 铜牌个数
bronze_medal = [13, 5, 2, 7, 5]
# 1.将x轴转换为数值
x = np.arange(len(areas))
# 2.设置图形宽度
width = 0.2
# 起始位置
gold_x = x
silver_x = x+width
bronze_x = x+2*width
plt.bar(gold_x, gold_medel, width=width, color='gold', label="金牌")
plt.bar(silver_x, silver_medal, width=width, color='silver', label="银牌")
plt.bar(bronze_x, bronze_medal, width=width, color='saddlebrown', label="铜牌")
plt.xticks(x+width, areas)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#准备数据
data = [[30, 25, 50, 20],
[40, 23, 51, 17],
[35, 22, 45, 19]]
x = np.arange(4)
fig = plt.figure()
#添加子图区域
ax = fig.add_axes([0,0,1,1])
width=0.25
#绘制柱状图
plt.bar(x, data[0], color='b', label='CS', width=width)
plt.bar(x+width, data[1], color='g', label='IT', width=width)
plt.bar(x+2*width, data[2], color='r', label='E&TC', width=width)
plt.xticks(x+width, labels=[2015, 2016, 2017, 2018])
plt.legend()
plt.show()

# %%
# 堆叠柱状图绘制
import numpy as np
import matplotlib.pyplot as plt
countries = ['USA', 'India', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 18, 10])
golds = np.array([46, 27, 26, 19, 17])
ind = np.arange(len(countries))
#绘制堆叠图
plt.bar(ind, golds, width=0.5, label='golds', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.5, label='silvers', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.5, label='bronzes', color='#CD853F')
#设置坐标轴
plt.xticks(ind, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.legend(loc="upper right")
plt.title("2019 Olympics Top Scorers")
plt.show()

# %% [markdown]
# ## Matplotlib 直方图

# %%
from matplotlib import pyplot as plt
import numpy as np
#创建图形对象和轴域对象
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
#绘制直方图
ax.hist(a, bins = [0,25,50,75,100], density=False, histtype='stepfilled')
#设置坐标轴
ax.set_title("histogram of result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no.of students')
plt.show()

# %%
# Implementation of matplotlib function
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0.0, 2.0, 201)
s = np.sin(2 * np.pi * t)

fig, [ax, ax1] = plt.subplots(2, 1)

ax.set_ylabel('y-axis')
ax.plot(t, s)
ax.grid(True)
ax.set_title('matplotlib.axes.Axes.cla() Example\n\n Sample Example',
             fontsize = 12, fontweight ='bold')

ax1.set_ylabel('y-axis')
ax1.set_xlabel('x-axis')
ax1.plot(t, s)
ax1.grid(True)
ax1.cla()
ax1.set_title('Above example with cla() function', fontsize = 12, fontweight ='bold')
plt.show()
